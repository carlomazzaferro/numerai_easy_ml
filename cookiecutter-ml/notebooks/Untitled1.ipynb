# %%
import sys
import os

os.getcwd()
# Out:
# '/Users/carlomazzaferro/Documents/Code/numerai_easy_ml/cookiecutter-ml/notebooks'

# %%
sys.path.append(os.getcwd().replace('notebooks', 'src'))

# %%
from models import LSTM
# Out:
# /Users/carlomazzaferro/anaconda/envs/OpenAI/lib/python3.6/site-packages/matplotlib/__init__.py:1085: UserWarning: Duplicate key in file "/Users/carlomazzaferro/.matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# ROOT: /Users/carlomazzaferro/Documents/Code/numerai_easy_ml/cookiecutter-ml/src/utils/../..

# %%
LSTM_MODEL = LSTM.LSTM(problem_type='regression')
# Out:
# Available data to be preprocessed: example_predictions.csv, numerai_tournament_data.csv, numerai_training_data.csv

# %%
LSTM_MODEL.generate_train_test('numerai_training_data.csv')
# Out:
# 'Data now accessible at /Users/carlomazzaferro/Documents/Code/numerai_easy_ml/cookiecutter-ml/src/utils/../../data/processed as csv files: xtrain.csv, xtest.csv, ytrain.csv, ytest.csv'

# %%
LSTM_MODEL.load_data()
# Out:
# 'Data now accessible as class attribute'

# %%
LSTM_MODEL.mod_input(to_np=True)

# %%
LSTM_MODEL.x_train
# Out:
# array([[[  1.51537000e+05,   5.07000000e-01,   4.61110000e-01, ...,
#            6.05690000e-01,   5.30970000e-01,   5.14930000e-01]],
#
#        [[  5.99280000e+04,   2.78160000e-01,   5.03180000e-01, ...,
#            4.12000000e-01,   6.17140000e-01,   4.20650000e-01]],
#
#        [[  1.12079000e+05,   4.87610000e-01,   5.48860000e-01, ...,
#            5.07850000e-01,   4.81820000e-01,   3.96560000e-01]],
#
#        ...,
#        [[  8.90570000e+04,   5.09800000e-01,   6.52790000e-01, ...,
#            4.15480000e-01,   4.35850000e-01,   3.02950000e-01]],
#
#        [[  2.01080000e+04,   6.25950000e-01,   3.10830000e-01, ...,
#            6.49620000e-01,   5.68370000e-01,   6.69800000e-01]],
#
#        [[  1.86300000e+03,   5.02590000e-01,   5.00240000e-01, ...,
#            5.17870000e-01,   5.05020000e-01,   4.54730000e-01]]])

# %%
import pandas
df = pandas.read_csv(dpath + LSTM_MODEL.raw_data_files[-1])

# %%
corr = LSTM_MODEL.x_train.drop(['id', 'era'], 1).corr()

# %%
corr.reset_index().as_matrix()
# Out:
# array([['feature1', 1.0, 0.3274745563841276, -0.7790894927947363,
#         0.5895398973229896, 0.5257415111749562, -0.331241432789439,
#         0.20191628960150687, -0.94620156160314, 0.4911241184824256,
#         -0.23052815148199654, 0.7322283181314572, 0.5737144240705532,
#         0.8818313585764375, -0.3961530086378323, 5.9781547183072286e-05,
#         0.8738705138211595, -0.8770332110748874, -0.756118522488675,
#         0.3136133615886962, -0.6871022716670838, -0.19946687814217956],
#        ['feature2', 0.3274745563841276, 1.0, -0.7379435477143971,
#         0.8440487870822595, 0.7235033160576011, 0.4893427805812322,
#         -0.25549049470123814, -0.2637238158311596, -0.4711257759826451,
#         0.7460293660348845, 0.7751962331611052, 0.8856187273021713,
#         0.6417863548855393, -0.3455179112214297, 0.22240020377791936,
#         0.5749457427656153, -0.6815320139210024, -0.7490848797028496,
# ...

# %%
Index= ['aaa', 'bbb', 'ccc', 'ddd', 'eee']
Cols = ['A', 'B', 'C', 'D']
import pandas, numpy
df = pandas.DataFrame(abs(numpy.random.randn(5, 4)), index=Index, columns=Cols)

sns.heatmap(df)

# %%
import seaborn as sns 

sns.heatmap(corr)

# %%
df.head()
# Out:
#        id   era data_type  feature1  feature2  feature3  feature4  feature5  \
# 0  140721  era1     train   0.26647   0.42487   0.81401   0.22889   0.27456
# 1    6942  era1     train   0.41334   0.47533   0.71847   0.40792   0.32433
# 2   97514  era1     train   0.48937   0.56030   0.59150   0.46432   0.42291
# 3   60256  era1     train   0.61195   0.65958   0.45877   0.56730   0.51889
# 4   30143  era1     train   0.43758   0.50085   0.60446   0.46663   0.47157
#
#    feature6  feature7   ...    feature13  feature14  feature15  feature16  \
# 0   0.55654   0.55310   ...      0.18847    0.77235    0.55002    0.20237
# 1   0.55806   0.59592   ...      0.32083    0.72435    0.63751    0.29143
# 2   0.54177   0.53542   ...      0.42195    0.62651    0.51604    0.42938
# 3   0.45049   0.56030   ...      0.54803    0.59120    0.58160    0.51828
# 4   0.59667   0.40161   ...      0.40535    0.54366    0.44763    0.37668
#
# ...

# %%
df = df.set_index('id')

# %%
x = df.drop(['era', 'data_type', 'target'], 1).as_matrix()
y = df['target'].as_matrix()

# %%
y
# Out:
# array([1, 1, 1, ..., 1, 0, 1])
